# %% [markdown]
# We will be working with publicly available airline passenger time series data. To start, let’s import the Pandas library and read the airline passenger data into a data frame

# %%
# Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from pandas.plotting import lag_plot
from statsmodels.tsa.stattools import adfuller
import warnings

# Setup
warnings.filterwarnings("ignore")

data=pd.read_csv(r'C:\Users\Vithushan\Downloads\airlines_passengers.csv')

# %% [markdown]
# Let’s display the first five rows of data

# %%
data.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %% [markdown]
# We can see that the data contains a column labeled “Month” that contains dates. In that column,
# the dates are formatted as year–month. We also see that the data starts in the year 1949.
# The second column is labeled Passengers, and it contains the number of passengers for the year–month. Let’s take a look at the last five records the data

# %%
data.tail()
# Out:
#        Month  Passengers
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432

# %% [markdown]
# We see that the data ends in 1960. The next thing we will want to do is convert the month column into a datetime object.
# This will allow it to programmatically pull time values like the year or month for each record.
# To do this, we use the Pandas to_datetime() method. Note that this process automatically inserts the first day of each month, which is basically a dummy value since we have no daily passenger data.

# %%
data.dtypes
# Out:
# Month         object
# Passengers     int64
# dtype: object

# %% [markdown]
# The next thing we can do is convert the month column to an index.

# %%
data['Month'] = pd.to_datetime(data['Month'])

# %%
data.dtypes
# Out:
# Month         datetime64[ns]
# Passengers             int64
# dtype: object

# %%
data.head()
# Out:
#        Month  Passengers
# 0 1949-01-01         112
# 1 1949-02-01         118
# 2 1949-03-01         132
# 3 1949-04-01         129
# 4 1949-05-01         121

# %%
data = data.set_index('Month')

# %%
data
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %% [markdown]
# Let’s generate a time series plot using Seaborn and Matplotlib. This will allow us to visualize the time series data.
# Import the libraries and generate the lineplot. Label the y-axis with Matplotlib “Number of Passengers”

# %%
# I imported both libaries before 

sns.lineplot(x=data.index, y=data.Passengers)
plt.title('Number of Passengers')
plt.show()

# %% [markdown]
# Stationarity is a key part of time series analysis. Import the augmented Dickey-Fuller test from the statsmodels package.

# %%
# Ho: userAcceleration.x is not stationary
# Ha: userAcceleration.x is stationary

from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# Let’s pass our data frame into the adfuller method.
# Here, we specify the autolag parameter as “AIC”, which means that the lag is chosen to minimize the information criterion

# %%
result = adfuller(data, autolag='AIC')
print('ADF Test Statistic: %.2f' % result[0])
print('5%% Critical Value: %.2f' % result[4]['5%'])
print('p-value: %.2f' % result[1])
# Out:
# ADF Test Statistic: 0.82
# 5% Critical Value: -2.88
# p-value: 0.99

# %% [markdown]
# Store our results in a dataframe display it

# %%
result = pd.DataFrame(result)
result
# Out:
#                                                    0
# 0                                           0.815369
# 1                                            0.99188
# 2                                                 13
# 3                                                130
# 4  {'1%': -3.4816817173418295, '5%': -2.884041834...
# 5                                         996.692931

# %% [markdown]
# Explain the results

# %%
'''
The value of the p parameter is equal to 0.99, which is high and for sure greater than 0.05 which means that I have to reject H0 hypothesis which stated that the data is stationary. 
The fact that the data is not stationary can be seen from the graph above, clearly the mean and the variance changes for diffrent time periods.
'''
# Out:
# '\nThe value of the p parameter is equal to 0.99, which is high and for sure greater than 0.05 which means that I have to reject H0 hypothesis which stated that the data is stationary. \nThe fact that the data is not stationary can be seen from the graph above, clearly the mean and the variance changes for diffrent time periods.\n'

# %% [markdown]
# Autocorrelation
# Checking for autocorrelation in time series data is another important part of the analytic process.
# This is a measure of how correlated time series data is at a given point in time with past values,
# which has huge implications across many industries. For example, if our passenger data has strong autocorrelation, we can assume that high passenger numbers today suggest a strong likelihood that they will be high tomorrow as well.
# Please calculate and show the autocorrelation

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(data)
plt.show()

# %% [markdown]
# Calculate partial autocorrelation

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(data)
plt.show()

# %% [markdown]
# Decomposition
# Trend decomposition is another useful way to visualize the trends in time series data.
# To proceed, let’s import seasonal_decompose from the statsmodels package:
# from statsmodels.tsa.seasonal import seasonal_decompose

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# Next, let’s pass our data frame into the seasonal_decompose method and plot the result:
# decompose =
# decompose.plot()
# plt.show()

# %%
decompose = seasonal_decompose(data)

# Plot
plt.rcParams.update({'figure.figsize': (10,10)})
decompose.plot().suptitle('Decomposed data', fontsize=22)

plt.show()

# %% [markdown]
# Can you describe the charts?

# %%
'''
In the first graph I see the original data so the time serires of passengers. 
In the next one I see the trend, so I can see that the number of passengers increases in time 
The third garph shows seasonality, so how data is repeated in time. 
FInally, the last graph is showing the residuals, so the noise that couldn't be inclouded in trend and seasonality
'''
# Out:
# "\nIn the first graph I see the original data so the time serires of passengers. \nIn the next one I see the trend, so I can see that the number of passengers increases in time \nThe third garph shows seasonality, so how data is repeated in time. \nFInally, the last graph is showing the residuals, so the noise that couldn't be inclouded in trend and seasonality\n"

# %% [markdown]
# Let's check the models on our dataset. Please note, if the dataset is non-stationary, you need to make it stationary

# %%
#to make data stationary I first try the diff method

data['Difference'] = data['Passengers'].diff()

# %%
#Now I check if the data is stationary 
result = adfuller(data.Difference.dropna())
print('ADF Test Statistic: %.2f' % result[0])
print('5%% Critical Value: %.2f' % result[4]['5%'])
print('p-value: %.2f' % result[1])
# Out:
# ADF Test Statistic: -2.83
# 5% Critical Value: -2.88
# p-value: 0.05

# %%
#p-value is equal to 0.05 which means that the data is not stationary

# %%
sns.lineplot(x=data.index, y=data.Difference)
plt.title('Difference')
plt.show()

# %%
# I will try to use another method to test stationarity
from statsmodels.tsa.stattools import kpss

result = kpss(data.Difference.dropna())
print(result)
print('KPSS Test Statistic: %.2f' % result[0])
print('5%% Critical Value: %.2f' % result[3]['5%'])
print('p-value: %.2f' % result[1])
# Out:
# (0.023897614400183967, 0.1, 7, {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})
# KPSS Test Statistic: 0.02
# 5% Critical Value: 0.46
# p-value: 0.10

# %%
'''
For the second test the p-value is below 0.10 so the data is not stationary, so I need to try another method I will try to do log and then diff 
'''
# Out:
# '\nFor the second test the p-value is below 0.10 so the data is not stationary, so I need to try another method I will try to do log and then diff \n'

# %%
import numpy as np
data['log'] = np.log(data.Passengers)
data['log'] = data['log'].diff()
data = data.drop(data.index[0])

# %%
sns.lineplot(x=data.index, y=data.log)
plt.title('Log Difference')
plt.show()

# %%
data.head()
# Out:
#             Passengers  Difference       log
# Month
# 1949-02-01         118         6.0  0.052186
# 1949-03-01         132        14.0  0.112117
# 1949-04-01         129        -3.0 -0.022990
# 1949-05-01         121        -8.0 -0.064022
# 1949-06-01         135        14.0  0.109484

# %%
#Now I check fo stationarity using two methods
result = adfuller(data.log.dropna())
print('ADF Test Statistic: %.2f' % result[0])
print('5%% Critical Value: %.2f' % result[4]['5%'])
print('p-value: %.2f' % result[1])
# Out:
# ADF Test Statistic: -2.72
# 5% Critical Value: -2.88
# p-value: 0.07

# %%
result = kpss(data.log.dropna())
print(result)
print('KPSS Test Statistic: %.2f' % result[0])
print('5%% Critical Value: %.2f' % result[3]['5%'])
print('p-value: %.2f' % result[1])
# Out:
# (0.038304469546740647, 0.1, 6, {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})
# KPSS Test Statistic: 0.04
# 5% Critical Value: 0.46
# p-value: 0.10

# %%
'''
p-value is equal to 0.07 so it is greater than 0.05 and I cannot reject the H0 hypothesis which means that the data is not stationary.
'''
# Out:
# '\np-value is equal to 0.07 so it is greater than 0.05 and I cannot reject the H0 hypothesis which means that the data is not stationary.\n'

# %%
from scipy.stats import boxcox

data['boxcox'],parameters= boxcox(data['Passengers'])
data['boxcox']=data['boxcox'].diff()

# %%
sns.lineplot(x=data.index, y=data.boxcox)
plt.title('Boxcox Difference')
plt.show()

# %%
result = adfuller(data.boxcox.dropna())
print('ADF Test Statistic: %.2f' % result[0])
print('5%% Critical Value: %.2f' % result[4]['5%'])
print('p-value: %.2f' % result[1])
# Out:
# ADF Test Statistic: -3.39
# 5% Critical Value: -2.88
# p-value: 0.01

# %%
'''
Now p-value is less than 0.05 which means that I can reject H0 hypothesis and the data is stationary
'''
# Out:
# '\nNow p-value is less than 0.05 which means that I can reject H0 hypothesis and the data is stationary\n'

# %% [markdown]
# MA(1)

# %%
from statsmodels.tsa.arima.model import ARIMA
mod = ARIMA(data.boxcox.dropna(), order=(0,0,1))
res = mod.fit()

# %% [markdown]
# Display the output

# %%
print(res.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 boxcox   No. Observations:                  142
# Model:                 ARIMA(0, 0, 1)   Log Likelihood                   5.890
# Date:                Thu, 15 Sep 2022   AIC                             -5.779
# Time:                        15:38:50   BIC                              3.088
# Sample:                    03-01-1949   HQIC                            -2.176
#                          - 12-01-1960
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0212      0.026      0.803      0.422      -0.031       0.073
# ma.L1          0.2915      0.103      2.817      0.005       0.089       0.494
# sigma2         0.0539      0.009      6.114      0.000       0.037       0.071
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.13   Jarque-Bera (JB):                 5.69
# Prob(Q):                              0.72   Prob(JB):                         0.06
# Heteroskedasticity (H):               1.55   Skew:                             0.17
# Prob(H) (two-sided):                  0.14   Kurtosis:                         2.08
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# I create predictions in order to calculate RMSE and compare it later with diffrent models
predictions_mod = res.predict(data.boxcox.index[-15],data.boxcox.index[-1])

# %%
from statsmodels.tools.eval_measures import rmse
rmse_1 = rmse(data.boxcox[-15:],predictions_mod)
rmse_1
# Out:
# 0.247273411379433

# %% [markdown]
# MA(2)

# %%
mod2 = ARIMA(data.boxcox.dropna(), order=(0,0,2))
res2 = mod2.fit()

# %% [markdown]
# Display the output

# %%
print(res2.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 boxcox   No. Observations:                  142
# Model:                 ARIMA(0, 0, 2)   Log Likelihood                   8.086
# Date:                Thu, 15 Sep 2022   AIC                             -8.173
# Time:                        15:39:27   BIC                              3.650
# Sample:                    03-01-1949   HQIC                            -3.368
#                          - 12-01-1960
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0208      0.018      1.161      0.246      -0.014       0.056
# ma.L1          0.2310      0.086      2.680      0.007       0.062       0.400
# ma.L2         -0.3318      0.076     -4.386      0.000      -0.480      -0.184
# sigma2         0.0521      0.009      5.725      0.000       0.034       0.070
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):                 6.85
# Prob(Q):                              0.73   Prob(JB):                         0.03
# Heteroskedasticity (H):               1.54   Skew:                            -0.13
# Prob(H) (two-sided):                  0.14   Kurtosis:                         1.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#Prediticons for model2
predictions_mod2 = res2.predict(data.boxcox.index[-15],data.boxcox.index[-1])

# %%
rmse_2 = rmse(data.boxcox[-15:],predictions_mod2)
rmse_2
# Out:
# 0.2569151739052019

# %% [markdown]
# AR(2)

# %%
mod3 = ARIMA(data.boxcox.dropna(), order=(2,0, 0))
res3 = mod3.fit()

# %%
print(res3.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 boxcox   No. Observations:                  142
# Model:                 ARIMA(2, 0, 0)   Log Likelihood                   6.873
# Date:                Thu, 15 Sep 2022   AIC                             -5.745
# Time:                        15:39:42   BIC                              6.078
# Sample:                    03-01-1949   HQIC                            -0.941
#                          - 12-01-1960
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0210      0.023      0.908      0.364      -0.024       0.066
# ar.L1          0.2563      0.103      2.479      0.013       0.054       0.459
# ar.L2         -0.1761      0.094     -1.880      0.060      -0.360       0.008
# sigma2         0.0531      0.009      5.949      0.000       0.036       0.071
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):                 6.03
# Prob(Q):                              0.83   Prob(JB):                         0.05
# Heteroskedasticity (H):               1.60   Skew:                             0.11
# Prob(H) (two-sided):                  0.11   Kurtosis:                         2.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#Prediticons for model3
predictions_mod3 = res3.predict(data.boxcox.index[-15],data.boxcox.index[-1])

# %%
rmse_3 = rmse(data.boxcox[-15:],predictions_mod3)
rmse_3
# Out:
# 0.24785126975894864

# %% [markdown]
# ARMA (?,?)

# %%
mod4 = ARIMA(data.boxcox.dropna(), order=(2,0, 2))
res4 = mod4.fit()

# %% [markdown]
# Display the output

# %%
print(res4.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 boxcox   No. Observations:                  142
# Model:                 ARIMA(2, 0, 2)   Log Likelihood                  22.190
# Date:                Thu, 15 Sep 2022   AIC                            -32.380
# Time:                        15:39:55   BIC                            -14.645
# Sample:                    03-01-1949   HQIC                           -25.173
#                          - 12-01-1960
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0223      0.002     12.790      0.000       0.019       0.026
# ar.L1          0.2594      0.160      1.625      0.104      -0.054       0.572
# ar.L2          0.1737      0.151      1.147      0.252      -0.123       0.471
# ma.L1         -0.2394      0.228     -1.049      0.294      -0.687       0.208
# ma.L2         -0.7529      0.198     -3.807      0.000      -1.140      -0.365
# sigma2         0.0419      0.011      3.807      0.000       0.020       0.063
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.26   Jarque-Bera (JB):                 5.49
# Prob(Q):                              0.61   Prob(JB):                         0.06
# Heteroskedasticity (H):               1.50   Skew:                            -0.11
# Prob(H) (two-sided):                  0.17   Kurtosis:                         2.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#Prediticons for model4
predictions_mod4 = res4.predict(data.boxcox.index[-15],data.boxcox.index[-1])

# %%
rmse_4 = rmse(data.boxcox[-15:],predictions_mod4)
rmse_4
# Out:
# 0.22883669092459089

# %% [markdown]
# ARIMA(?,?)

# %%
from statsmodels.tsa.arima.model import ARIMA

# 1,1,2 ARIMA Model
mod5 = ARIMA(data.boxcox.dropna(), order=(2,1,2))
res5 = mod5.fit()

# %% [markdown]
# Display the output

# %%
print(res5.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 boxcox   No. Observations:                  142
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                   6.289
# Date:                Thu, 15 Sep 2022   AIC                             -2.578
# Time:                        15:40:08   BIC                             12.166
# Sample:                    03-01-1949   HQIC                             3.414
#                          - 12-01-1960
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5733      0.161     -3.551      0.000      -0.890      -0.257
# ar.L2          0.0505      0.122      0.414      0.679      -0.188       0.289
# ma.L1         -0.1171     65.398     -0.002      0.999    -128.295     128.061
# ma.L2         -0.8829     57.756     -0.015      0.988    -114.082     112.316
# sigma2         0.0517      3.383      0.015      0.988      -6.579       6.682
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 5.28
# Prob(Q):                              0.98   Prob(JB):                         0.07
# Heteroskedasticity (H):               1.40   Skew:                             0.09
# Prob(H) (two-sided):                  0.25   Kurtosis:                         2.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#Prediticons for model5
predictions_mod5 = res5.predict(data.boxcox.index[-15],data.boxcox.index[-1])

# %%
rmse_5 = rmse(data.boxcox[-15:],predictions_mod4)
rmse_5
# Out:
# 0.22883669092459089

# %% [markdown]
# Let’s calculate root mean squared error (RMSE) for all the models. Explain the values

# %%
# Since I calaculated earlier RMSE for all of the models I will just put it into one dataframe with AIC in order to compare models

# %% [markdown]
# Calculate AIC

# %%
res5.aic
# Out:
# -2.5775685432745625

# %%
comparison_models = pd.DataFrame({'model': ['MA(1)','MA(2)', 'AR(2)', 'ARMA(2,2)','ARIMA(2,1,2)'],'RMSE': [rmse_1, rmse_2,rmse_3,rmse_4,rmse_5], 'AIC': [res.aic, res2.aic, res3.aic, res4.aic, res5.aic]})

# %%
comparison_models.set_index('model')
# Out:
#                   RMSE        AIC
# model
# MA(1)         0.247273  -5.779298
# MA(2)         0.256915  -8.172981
# AR(2)         0.247851  -5.745080
# ARMA(2,2)     0.228837 -32.380189
# ARIMA(2,1,2)  0.228837  -2.577569

# %%
'''
For both parameters i.e. RMSE and AIC the lower the value the better. Taking that into accout the best model seems to be ARMA(2,2). The rest of the models give diffrent order of values in terms of these two parameters so it is difficult to say what is the exact oredr of models baisng on the two parameers. Taking into account only RMSE the ARIMA and ARMA model are the best, followed by AR and both MA models. 
On the other hand taking into account only AIC parameter ARMA(2,2) model is the best folowed by MA(2) both MA(1) and AR(2) and the worst one ARIMA(2,1,2).
'''
# Out:
# '\nFor both parameters i.e. RMSE and AIC the lower the value the better. Taking that into accout the best model seems to be ARMA(2,2). The rest of the models give diffrent order of values in terms of these two parameters so it is difficult to say what is the exact oredr of models baisng on the two parameers. Taking into account only RMSE the ARIMA and ARMA model are the best, followed by AR and both MA models. \nOn the other hand taking into account only AIC parameter ARMA(2,2) model is the best folowed by MA(2) both MA(1) and AR(2) and the worst one ARIMA(2,1,2).\n'
