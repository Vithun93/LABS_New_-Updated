# %%
import numpy as np
import random
import scipy.stats as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
imdb=pd.read_csv(r"C:\Users\Vithushan\Downloads\imdb.csv")
imdb
# Out:
#       Unnamed: 0                          title    year            kind  \
# 0              0                Dinosaur Planet  2003.0  tv mini series
# 1              1                      Character  2021.0           movie
# 2              2              Get Up and Dance!  1994.0     video movie
# 3              3  The Rise and Fall of El Chapo  2016.0        tv movie
# 4              4                    Sick - IMDb     NaN             NaN
# ...          ...                            ...     ...             ...
# 9821        9821            All Monsters Attack  1969.0           movie
# 9822        9822                   Fidel Castro  2005.0         episode
# 9823        9823                          Epoch  2001.0        tv movie
# 9824        9824                    The Company  2003.0           movie
# 9825        9825                       Predator  1987.0           movie
#
#                                               genre  rating      vote  \
# ...

# %%
imdb.isna().sum()
# Out:
# Unnamed: 0       0
# title            1
# year            70
# kind            38
# genre           93
# rating         877
# vote           877
# country        665
# language       793
# cast           344
# director      1860
# composer      3622
# writer        1656
# runtime       1056
# dtype: int64

# %%
imdb = imdb.dropna(axis=1 ,thresh = int(len(imdb)*0.80))

imdb=pd.DataFrame(imdb)
imdb
# Out:
#       Unnamed: 0                          title    year            kind  \
# 0              0                Dinosaur Planet  2003.0  tv mini series
# 1              1                      Character  2021.0           movie
# 2              2              Get Up and Dance!  1994.0     video movie
# 3              3  The Rise and Fall of El Chapo  2016.0        tv movie
# 4              4                    Sick - IMDb     NaN             NaN
# ...          ...                            ...     ...             ...
# 9821        9821            All Monsters Attack  1969.0           movie
# 9822        9822                   Fidel Castro  2005.0         episode
# 9823        9823                          Epoch  2001.0        tv movie
# 9824        9824                    The Company  2003.0           movie
# 9825        9825                       Predator  1987.0           movie
#
#                                               genre  rating      vote  \
# ...

# %%
imdb = imdb[imdb['director'].notna()]
imdb
# Out:
#       Unnamed: 0                         title    year         kind  \
# 1              1                     Character  2021.0        movie
# 2              2             Get Up and Dance!  1994.0  video movie
# 4              4                   Sick - IMDb     NaN          NaN
# 5              5                         8 Man  1992.0        movie
# 6              6  What the #$*! Do We (K)now!?  2004.0        movie
# ...          ...                           ...     ...          ...
# 9821        9821           All Monsters Attack  1969.0        movie
# 9822        9822                  Fidel Castro  2005.0      episode
# 9823        9823                         Epoch  2001.0     tv movie
# 9824        9824                   The Company  2003.0        movie
# 9825        9825                      Predator  1987.0        movie
#
#                                                   genre  rating      vote  \
# 1                       ['Crime', 'Horror', 'Thriller']     8.3      46.0
# ...
