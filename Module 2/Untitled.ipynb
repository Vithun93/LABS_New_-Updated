# %%
import pandas as pd
import numpy as np
import math

# %%
df=pd.read_csv(r"C:\Users\Vithushan\Downloads\join_data.csv")
df
# Out:
#        YR_MO   CALL_DATE  c_AGENT_KEY  CALLS  HANDLE_TIME  CALL_REGEN  \
# 0     201706  2017-06-01        12465     34        25710           5
# 1     201706  2017-06-01        12466     35        25039           4
# 2     201706  2017-06-01        12467     38        24436           6
# 3     201706  2017-06-01        12468     38        24923           5
# 4     201706  2017-06-01        12469     34        24371           4
# ...      ...         ...          ...    ...          ...         ...
# 1520  201708  2017-08-31        12486     28        25714           6
# 1521  201708  2017-08-31        12487     29        25834           7
# 1522  201708  2017-08-31        12488     33        25229           7
# 1523  201708  2017-08-31        12489     29        25006           6
# 1524  201708  2017-08-31        12490     29        24662           6
#
#       CALLS_WITH_OFFER  CALLS_WITH_ACCEPT  CALLS_OFFER_APPLIED  TRANSFERS  \
# ...

# %%
df.groupby("TEAM_LEAD_NAME").agg({"c_AGENT_KEY":"count"})
# Out:
#                    c_AGENT_KEY
# TEAM_LEAD_NAME
# Jimson, Bill               492
# Oferten, Quinton           526
# Winnerson, Aceona          507
