# %% [markdown]
# # Before your start:
# - Read the README.md file.
# - Comment as much as you can and use the resources (README.md file).
# - Happy learning!

# %%
# Libraries
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import statistics

# %% [markdown]
# # Challenge 1 - Generate and Plot Normal Distributions
# #### Step 1: Generate samples and test normal distribution.
#
# Use mean=50, standard_deviation=5, and sample_size=[10, 50, 500, 5000] to generate 4 random samples that are normally distributed.
#
# **Hint**: Read the documentation for `scipy.stats.norm.rvs`. The function will help you create the normal random samples.

# %%
# your code here
mean= 50
standard_devaition=5
sample_size=[10,50,500,5000]

# %%
sample1 = stats.norm.rvs(loc = mean, scale = standard_devaition, size = sample_size[0])
sample2 = stats.norm.rvs(loc = mean, scale = standard_devaition, size = sample_size[1])
sample3 = stats.norm.rvs(loc = mean, scale = standard_devaition, size = sample_size[2])
sample4 = stats.norm.rvs(loc = mean, scale = standard_devaition, size = sample_size[3])
print(sample1)
print(sample2)
print(sample3)
print(sample4)
# Out:
# [56.10406603 45.73476413 44.90865245 50.78288741 47.31118436 59.87712172
#  54.20614496 52.07847707 49.22000795 54.76993648]
# [51.58437499 57.40311206 46.95116251 42.05187997 43.63490663 47.27329473
#  52.68612413 46.48893385 48.95457891 50.8926583  53.76658073 44.38800419
#  42.92459441 51.90614028 48.25521242 49.62368385 39.14867961 48.79074927
#  42.04689891 45.73962271 51.6000776  50.16385602 52.54789185 55.88979724
#  51.21318759 46.62791728 55.46953882 53.13118167 44.83710869 46.36684246
#  55.48931612 49.00009078 51.01488969 50.46317697 52.56286298 48.08543148
#  50.0088904  41.03926842 47.66729116 40.23324294 47.07449351 47.30883585
#  51.25518581 56.75014037 48.87331093 56.92135295 45.10716187 51.52963732
#  52.66639007 58.44677338]
# [49.52936133 49.61681135 41.32786785 45.87373602 44.52602192 57.42453874
#  47.95443317 48.44433854 54.39661092 51.39322773 52.08639438 52.61116326
#  50.3067465  49.36065578 42.58590132 44.4537705  47.76110164 56.68639763
#  56.06667149 52.69820694 53.4322353  53.58927049 45.35308145 47.69967179
#  53.20250861 52.44122683 57.40244129 55.15633624 52.2051959  51.2135996
#  50.77681089 58.1975358  48.51965102 50.30656804 48.853418   46.55306163
#  48.41761383 45.43594714 48.59761154 53.02317912 52.94267066 51.00933705
#  48.5864178  47.38863827 51.41258912 38.39927459 47.56996263 52.56230795
#  49.80001089 59.03246413 46.23390515 42.69574393 43.61978459 54.93592289
#  42.1088619  55.80175624 49.96843084 48.54634526 46.93284126 44.55366259
#  52.98442094 49.39590027 44.45220531 56.85706711 44.25164199 51.28394071
#  51.61252246 51.27029316 51.61758822 47.31971649 42.0795067  48.63781629
#  48.99537294 52.52885911 53.91674143 52.95346686 54.51626484 52.20202284
#  43.47393128 49.29196917 53.66466775 52.2423123  42.52662545 46.20750727
#  56.74299302 48.85368668 44.30548778 47.01123522 51.90511681 55.34698489
#  40.95553404 49.00980624 51.63041486 48.69963347 42.09934879 52.9116014
#  51.46844486 50.40397406 41.74569831 54.34447954 52.13502983 59.50081649
#  56.44131108 42.32485503 45.50627727 54.72815191 53.6553387  53.18923614
#  46.34282407 57.96950693 49.97029398 52.46696065 55.99550243 54.36408975
#  47.17209994 55.95858022 52.29199724 46.30465185 51.85280086 49.19323492
#  49.79361462 43.6315874  48.66480948 42.86679356 60.95232823 59.5689913
#  56.02579082 50.16605867 48.99387999 55.90022871 49.86054839 49.36653622
#  52.08659922 47.9514403  45.45253599 54.17586605 36.08907834 53.01354147
#  43.19091085 49.50830694 58.57833255 61.56724646 49.01884449 47.27008151
#  45.07745328 50.41920564 44.67077478 57.93529517 44.95337625 42.64833591
#  54.8589086  46.89945318 46.09120579 53.66692741 55.58836049 57.59685402
#  54.97153112 49.10202531 50.00004073 52.28284406 48.43461052 51.89898043
#  44.59421168 58.01018373 43.16812687 48.1589324  60.77239317 51.61256036
#  58.9021829  48.57781243 44.54421747 38.2143942  50.6591809  46.98090143
#  51.65559701 55.1849797  49.90488111 48.55426514 44.85517871 50.10342231
#  53.27625736 46.48338038 51.44782319 53.88856877 51.96314296 42.59233316
#  48.03880849 51.73678868 49.78441512 51.56724162 46.21607886 45.19732751
#  48.44151716 52.06062342 52.49936579 53.43696312 46.87123027 53.43691926
#  49.71264113 54.76791537 51.40450403 45.88093653 51.90171601 52.9213572
#  56.31550641 54.88906344 44.7350824  47.69044054 54.0681965  50.13405236
#  47.57688316 49.99408782 46.24856251 52.75484085 47.99099185 45.10610662
#  49.56235889 57.44282646 46.36543047 54.03886645 46.64812896 50.21079516
#  53.92062585 52.00928381 51.64435308 59.60802538 49.05236356 45.98779147
#  51.57727752 56.24920259 41.83677814 45.84227456 56.65742091 37.83565729
#  44.36678966 52.3591482  49.60766558 51.68170019 44.55982983 61.79193942
#  49.11612557 60.69774549 51.90192968 42.1942598  49.53357554 47.7534799
#  50.36094943 51.20325458 51.07256963 54.98798583 48.19521838 42.6578448
#  57.12662313 53.41234539 55.83643905 55.09385083 53.78617419 43.00948003
#  52.0072421  48.0640332  53.57812619 46.21110213 46.15278217 46.1397546
#  54.33432173 52.73718357 51.84847395 47.29877194 43.09719518 41.06088895
#  43.16438346 58.02342101 50.66118187 58.04292968 47.91656102 44.68498613
#  40.01161356 43.0171411  42.84598624 42.92261981 54.06865055 48.75438481
#  47.88144209 44.27818525 53.92301348 54.92384201 46.55588776 50.07765662
#  50.43295168 50.55372006 48.2240476  47.97501617 57.47117466 49.69593084
#  49.07092505 48.62424576 56.47047903 47.11705077 46.17818767 54.819161
#  58.59101072 47.80057975 52.89792253 49.25380654 52.57101059 39.74554872
#  52.77818611 57.28559536 53.41751326 41.6078946  42.33762403 54.75885585
#  57.12895378 50.25266871 36.29396667 47.06132693 49.36634116 55.38662088
#  40.31546936 51.89291143 49.30168318 46.55970651 50.27950497 47.65599264
#  53.29432638 38.36466174 43.69949262 41.93499744 52.90367756 59.28301225
#  47.43097849 49.24180856 48.01382223 51.43644325 46.88991416 47.11129073
#  43.50474289 49.46091856 54.74678468 51.55140257 52.8760053  53.41606523
#  51.97653991 49.69432084 43.65348074 53.83658749 52.90414235 47.91154497
#  40.74121907 55.97719093 58.03006695 53.52347564 47.11878217 52.21670896
#  55.43972923 47.07653877 45.73602686 46.48085575 43.25912291 48.72717624
#  48.33134874 54.44583297 50.74723653 50.75756539 45.32100219 55.35616096
#  50.18826052 55.55014116 49.5031198  52.76813999 49.72839547 43.07268452
#  60.59172416 52.38265273 44.99106935 54.03626033 46.32438187 41.18653426
#  58.62780353 52.74608138 47.19241063 61.68899261 49.28097292 52.69735606
#  40.57629048 51.05329496 46.97559996 46.78738906 46.48356129 50.7571827
#  45.95247112 44.27066802 47.81584545 48.93116514 55.13977425 49.28297919
#  53.75322301 48.18191802 50.69059597 47.28211139 45.75249184 45.33674501
#  51.73050226 53.55384386 50.67953377 51.62791715 52.54054919 50.02406395
#  47.77512514 40.81687165 55.21671506 51.83403386 48.30818561 49.01439829
#  54.534612   49.1193123  48.07223313 53.17864128 41.86673388 56.1150946
#  56.16356642 56.01636948 54.33050425 50.5764104  44.07325221 57.59661929
#  42.20239784 49.26416634 50.55156805 55.14441253 46.60329213 43.94717693
#  42.70994807 43.71912846 46.53937489 51.66301684 48.7826059  55.24389353
#  52.96850854 47.80273247 45.45587107 47.79793554 52.073068   53.75970807
#  53.75572707 47.69838163 53.6670709  47.19921274 43.37660073 44.49471447
#  48.10803549 40.5030736  42.3651529  47.40460229 54.1493061  44.39500842
#  47.43075702 47.62289932 49.70237871 45.61889736 47.52987653 47.11455971
#  46.19221681 51.4407459  50.75334644 60.77127232 45.66287263 49.33061378
#  44.51776    52.84034026 52.05366842 56.74492418 54.49625381 51.74899045
#  52.06994563 52.48848593 44.43894289 56.34176397 49.62957031 37.09463207
#  57.72263459 47.84202264 45.18208205 51.92940342 43.36314785 45.75209749
#  53.16435359 54.70656384 51.54365834 61.73850958 51.25484444 48.75043347
#  52.09503325 48.67006667 49.13260322 45.69996722 46.93267191 41.70062664
#  48.09590115 48.7486794 ]
# [51.35240049 54.9069467  54.65968281 ... 41.34916098 57.12844354
#  43.87463646]

# %%
print(len(sample1))
print(len(sample2))
print(len(sample3))
print(len(sample4))
# Out:
# 10
# 50
# 500
# 5000

# %% [markdown]
# #### Step 2: Plot normal distributions.
#
# To check the shape of the samples you have just created, you can use matplotlib. For example, you can use it to plot a histogram of each sample.
#
# If you did, your outputs would be really similar to the ones below:
#
# ![normal distributions with different sample sizes](../images/ch-1.png)

# %%
fig, [ax1, ax2, ax3, ax4] = plt.subplots(1,4)
fig.set_figheight(5)
fig.set_figwidth(10)

ax1.hist(sample1,bins=20)
ax1.set_title('n=10')

ax2.hist(sample2,bins=20)
ax2.set_title('n=50')

ax3.hist(sample3,bins=20)
ax3.set_title('n=500')

ax4.hist(sample4,bins=20)
ax4.set_title('n=5000')

plt.show()

# %% [markdown]
# #### Compare the distributions above. What do you observe? Explain with the Central Limit Theorem.

# %%
"""
With the increasing sample size, the distribution of the sample is approching normal distribution. 
The Central Limit Theorem states that for the pupulation with the unknows distribution the means of sample from that population have a normal distribution. 
In this example I generated the samples from the population of the normal distribution thus the distributions of that samples are also normal, but it is more clear when the sample is large enough. 
"""
# Out:
# '\nWith the increasing sample size, the distribution of the sample is approching normal distribution. \nThe Central Limit Theorem states that for the pupulation with the unknows distribution the means of sample from that population have a normal distribution. \nIn this example I generated the samples from the population of the normal distribution thus the distributions of that samples are also normal, but it is more clear when the sample is large enough. \n'

# %% [markdown]
# #### Bonus: Plot normal distributions.
#
# Even though you still don't know how to use matplotlib, as a bonus challenge, you can try to reproduce the plot above using the samples you have created. This plotting library will be introduced later this week, so don't worry if you don't manage to get the results you want now: you can always come back to solve this challenge later.

# %%
# your code here
sample4.sort()
mean_s4 = statistics.mean(sample4)
std_s4 = statistics.stdev(sample4)
plt.plot(sample4, stats.norm.pdf(sample4, mean, standard_devaition))
plt.show()

# %% [markdown]
# # Challenge 2 - Plot Probability Mass Function (PMF)

# %% [markdown]
# ### Background knowledge
#
# [PMF](https://en.wikipedia.org/wiki/Probability_mass_function) shows the probability distribution of a **discrete random variable**. A [discrete random variable](https://en.wikipedia.org/wiki/Random_variable#Discrete_random_variable) has random numeric values that are not continuous. For example, the number of people in a household can only be integers but not floats. Therefore the number of people in a household is a discrete variable.
#
# ### Challenge
#
# We assume that the probability of clicking an advertisement in a Youtube video is 0.15. We have a sample of 5 people who watched the video and we want to plot the PMF for a binomial distribution.
#
# #### Step 1: Create the binomial distribution mentioned above. Store the result in a variable called `dist`.
# **Hint**: use binom from `scipy.stats.binom`. This object takes *n* and *p* as shape parameters, where *n* is the number of independent experiments and *p* the probability of success of the experiment.

# %%
# your code here
n=5
p=0.15
dist= stats.binom(n=5, p=0.15)

# %% [markdown]
# #### Step 2: Plot the PMF of the distribution.
# To do it, run the code in the cell below.
#
# **Hint**: Your output should look like the one below:
#
# ![binom 10](../images/ch-2.png)

# %%
# run this code
x = range(n)

fig, ax = plt.subplots(1, 1)

plt.plot(x, dist.pmf(x))

plt.show()

# %% [markdown]
# #### Step 3: Explain what you observe from the plot above.

# %%
"""
I see the number of sucess and thier corresponding probability. Thus the most probable is that noone will click. Then than one person will clike, followed by 2 person clicking etc. 
"""
# Out:
# '\nI see the number of sucess and thier corresponding probability. Thus the most probable is that noone will click. Then than one person will clike, followed by 2 person clicking etc. \n'

# %% [markdown]
# #### Step 4: Now plot PMF with 50, 500, and 5000 visitors.
# To plot the PMF, you can copy the code given above and replace variable `dist` for the name of the variables where you have stored the new binomial objects for 50, 500 and 5000 visitors.

# %%
# your code here
n1, n2, n3, n4 = 5, 50, 500, 5000
dist1=stats.binom(n=n1, p=0.15)
dist2=stats.binom(n=n2, p=0.15)
dist3=stats.binom(n=n3, p=0.15)
dist4=stats.binom(n=n4, p=0.15)

x1, x2, x3, x4 = range(n1), range(n2), range(n3), range(n4)

fig, [ax1, ax2,ax3, ax4] = plt.subplots(1, 4)

fig.set_figheight(5)
fig.set_figwidth(16)

ax1.plot(x1, dist1.pmf(x1))
ax1.set_title('n=5')

ax2.plot(x2, dist2.pmf(x2))
ax2.set_title('n=50')

ax3.plot(x3, dist3.pmf(x3))
ax3.set_title('n=500')

ax4.plot(x4, dist4.pmf(x4))
ax4.set_title('n=5000')
# Out:
# C:\Users\Vithushan\anaconda3\lib\site-packages\scipy\stats\_discrete_distns.py:67: RuntimeWarning: divide by zero encountered in _binom_pdf
#   return _boost._binom_pdf(x, n, p)
# Text(0.5, 1.0, 'n=5000')

# %% [markdown]
# #### Step 5: What did you notice from the distribution plots? Comment your findings.

# %%
"""
Can observe that the highest probability of clicking is shifting to the left with the increasing sample size. This for only 5 peol=ple the highest proability was observed for noone clicking. For sample of 50, this number is below 10. For sample of 500 this number is below 100 etc. 

"""
# Out:
# '\nCan observe that the highest probability of clicking is shifting to the left with the increasing sample size. This for only 5 peol=ple the highest proability was observed for noone clicking. For sample of 50, this number is below 10. For sample of 500 this number is below 100 etc. \n\n'

# %% [markdown]
# # Challenge 3
# #### Step 1: Research the Poisson distribution. Write about your own understanding of the Poisson distribution.

# %%
"""
It is a distribution used for discreate variable. It si used to show how many times an event occured during a given period of time. Used often for to answer quastion how probable is that something will happen x times.
Example of uses: 
-schedulling optimal system 
-estimating of a number of car crashes in a city of a given size
-numerb of customers on a given day/time of day

It is given by the formula: 
P(x; μ) = (e**(-μ)) (μ**x) / x!

where
x- number of occurences
μ - is the expected value
"""
# Out:
# '\nIt is a distribution used for discreate variable. It si used to show how many times an event occured during a given period of time. Used often for to answer quastion how probable is that something will happen x times.\nExample of uses: \n-schedulling optimal system \n-estimating of a number of car crashes in a city of a given size\n-numerb of customers on a given day/time of day\n\nIt is given by the formula: \nP(x; μ) = (e**(-μ)) (μ**x) / x!\n\nwhere\nx- number of occurences\nμ - is the expected value\n'

# %% [markdown]
# #### Step 2: A website has an average of 300 visits per day. What is the probability of getting 320 visitors in a day?
#
# **Hint**: use `scipy.stats.poisson.pmf`.

# %%
# your code here
visits = 320
mu =300
stats.poisson.pmf(visits,mu)
# Out:
# 0.011612348610402475

# %% [markdown]
# #### Step 3: What is the probability of getting 60 visits?

# %%
# your code here
visits = 60
mu =300
stats.poisson.pmf(visits,mu)
# Out:
# 2.622743762294515e-64

# %% [markdown]
# #### Step 4: Create a list to store the Poisson distribution probabilities for 0 to 1000 visitors. Store your list in a variable called `arr`.

# %%
# your code here
arr = []
mu = 300
for num in range(1001):
    arr.append(stats.poisson.pmf(num,mu))

# %% [markdown]
# #### Step 5: Plot the probabilities.
# To do it, run the code in the cell below. Your plot should look like the one below:
#
# ![poisson distribution](../images/ch-3.png)

# %%
# run this code
plt.plot(arr)
plt.show()

# %% [markdown]
# # Challenge 4 - Central Limit Theorem
#
# A delivery company needs 35 minutes to deliver a package, with a standard deviation of 8 minutes. Suppose that in one day, they deliver 200 packages.
#
# **Hint**: `stats.norm.cdf` can help you find the answers.
#
# #### Step 1: What is the probability that the mean delivery time today is between 30 and 35 minutes?

# %%
# your code here
# your code here
mean = 35 
stdev = 8
n = 200
stats.norm.cdf(35, loc=mean, scale=stdev) - stats.norm.cdf(30, loc=mean, scale=stdev)
# Out:
# 0.23401447095129946

# %%
#The probability of that is 23%

# %% [markdown]
# #### Step 2: What is the probability that in total, it takes more than 115 hours to deliver all 200 packages?

# %%
# your code here
115*60/200
# Out:
# 34.5

# %%
1-stats.norm.cdf(34.5, loc=mean, scale=stdev)
# Out:
# 0.5249176690292472

# %% [markdown]
# # Challenge 5 - Normal Variables
# The value (in thousands) of the monthly sales of a publishing company follows a normal distribution with a mean equal to 200 and a standard deviation equal to 40.
#
# <div align="center">$X → N(200,40)$</div>
#
# **Hint**: `stats.norm.cdf` can help you find the answers.
#
# #### Step 1: Find the probability that the monthly sales are more than 300.

# %%
# your code here
1-stats.norm.cdf(300, loc=200, scale=40)
# Out:
# 0.006209665325776159

# %%
#The probability of the monthly sales being higher than 300 is 0.6%

# %% [markdown]
# #### Step 2: Find the probability that the monthly sales fall between 160 and 240.

# %%
# your code here
stats.norm.cdf(240, loc=200, scale=40)-stats.norm.cdf(160, loc=200, scale=40)
# Out:
# 0.6826894921370859

# %% [markdown]
# #### Step 3: Find the probability that the monthly sales do not exceed 150.

# %%
# your code here
stats.norm.cdf(150, loc=200, scale=40)
# Out:
# 0.10564977366685535

# %% [markdown]
# #### Step 4: Find the probability that the monthly sales exceed 3000.

# %%
# your code here
1-stats.norm.cdf(3000, loc=200, scale=40)
# Out:
# 0.0

# %% [markdown]
# # Challenge 6 - Poisson distribution
# The mean number of violent robberies per month that are registered in a particular barrio is 4.
#
# **Hint**: `stats.poisson.cdf` can help you find the answers.
#
# #### Step 1: Find the probability that in a particular month there is no violent robbery.

# %%
# your code here
stats.poisson.cdf(0,4)
# Out:
# 0.018315638888734182

# %% [markdown]
# #### Step 2: Find the probability that there are at least 1 robbery in a given month.

# %%
# your code here
1-stats.poisson.cdf(1,4)
# Out:
# 0.9084218055563291

# %% [markdown]
# #### Step 3: Find the probability that there are between 2 and 6 (inclusive) robberies in a given month.

# %%
# your code here
stats.poisson.cdf(6,4)-stats.poisson.cdf(2,4)
# Out:
# 0.6512227160438819

# %% [markdown]
# #### Step 4: Find the probability that there are more than 2 robberies in 15 days.

# %%
# your code here
1-stats.poisson.cdf(4,4)
# Out:
# 0.3711630648201266
